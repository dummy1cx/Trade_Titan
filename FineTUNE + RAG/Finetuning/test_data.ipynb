# %%
## For experiment with all the LLM I have pre processed and devided the dataset by taking a random 10%
## of the dataset. which will help i finetuning the model
## based on the output and result I will be taking the original dataset for further use

import pandas as pd
from pathlib import Path
import json

df = pd.read_parquet("/content/train-00000-of-00001.parquet")

# %%
df.head(5)
# Out:
#                                             question  \
# 0  What area did NVIDIA initially focus on before...
# 1  What are some of the recent applications of GP...
# 2  What significant invention did NVIDIA create i...
# 3  How does NVIDIA's platform strategy contribute...
# 4  What does NVIDIA's CUDA programming model enable?
#
#                                               answer  \
# 0           NVIDIA initially focused on PC graphics.
# 1  Recent applications of GPU-powered deep learni...
# 2                   NVIDIA invented the GPU in 1999.
# 3  NVIDIA's platform strategy brings together har...
# 4  NVIDIA's CUDA programming model opened the par...
#
#                                              context ticker    filing
# 0  Since our original focus on PC graphics, we ha...   NVDA  2023_10K
# 1  Some of the most recent applications of GPU-po...   NVDA  2023_10K
# 2  Our invention of the GPU in 1999 defined moder...   NVDA  2023_10K
# ...

# %%
len(df.columns)
# Out:
# 5

# %%
len(df)
# Out:
# 7000

# %%
print(df.shape[0])
# Out:
# 7000

# %%
print(df.shape[1])
# Out:
# 5

# %%
## For finetuning I am slighlt changing the dataset. to save time and computaional resources I am using a random 10% of the dataset for improved efficiency
df_sample = df.sample(frac=0.1, random_state=42)

# %%
df_sample.shape
# Out:
# (700, 5)

# %%
df_sample.head(5
               )
# Out:
#                                                question  \
# 6500  What services does Iron Mountain provide to pr...
# 2944   How is inventory valued for financial reporting?
# 2024  Where can details about legal proceedings be f...
# 263   What financial model does the company use to e...
# 4350  What are the two reporting business segments o...
#
#                                                  answer  \
# 6500  Iron Mountain provides services such as storin...
# 2944  Inventory is valued at standard cost adjusted ...
# 2024  Part II, Item 8, in the Notes to the Consolida...
# 263   The company uses the Black-Scholes option-pric...
# 4350  The two reporting business segments of the com...
#
#                                                 context ticker    filing
# 6500  Iron Mountain helps organizations protect thei...    IRM  2023_10K
# 2944  We value inventory at standard cost, adjusted ...    AMD  2023_10K
# ...

# %%
## saving only the required columsn for finetuning
data_ft = df_sample[['question','answer','context']].copy()

# %%
## Converting the dataframe to jsonl format
data_ft.to_json("updated_data.jsonl", orient="records", lines=True, force_ascii=False)
