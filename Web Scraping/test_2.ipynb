# %% [markdown]
# Selenium

# %%
### practice file

# %%
from selenium import webdriver

driver = webdriver.Chrome()

driver.maximize_window()

url="https://www.bbc.co.uk/news"

driver.get(url)

print(f"Title : {driver.title}")
print(f"Current URL : {driver.current_url}")

driver.save_screenshot('screenshot.png')
print("\nscreenshot captured!")

driver.quit()
# Out:
# Title : Home - BBC News
# Current URL : https://www.bbc.co.uk/news
#
# screenshot captured!

# %%
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome()
driver.maximize_window()

url = 'https://www.google.com'
driver.get(url)

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()

driver.maximize_window()

url = 'https://www.ibm.com/think/topics/machine-learning'

driver.get(url)

# time.sleep(2)

# search_pop_up_xpath = '//*[@id="L2AGLb"]/div'
# search_pop_up = driver.find_element(by = By.XPATH, value = search_pop_up_xpath)
# search_pop_up.click()


# search_bar_xpath = '//*[@id="APjFqb"]'

# search_bar = driver.find_element(by = By.XPATH, value = search_bar_xpath)

## enter the input in the search box

# search_bar.send_keys("machine learning")
# time.sleep(1)

##Clear the fields
# time.sleep(3)
# search_bar.clear()
# time.sleep(1)

#search_bar.send_keys(Keys.ENTER)

# clear_robo = '//*[@id="recaptcha-anchor"]/div[1]'
# clear_r = driver.find_element(by=By.XPATH, value = clear_robo)
# clear_r.click()
